# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notebook is my first peer-graded assignment and I will be reviewing Data Science Tools and Ecosystem.

# %% [markdown]
# Objectives
#
# 1. Create a Jupyter Notebook with markdown and code cells
# 2. Identify the criteria and roles for determining the language to learn
# 3. List examples of the various libraries: scientific, visualization, machine learning, and deep learning
# 4. Describe how to use the notebooks in JupyterLab

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
#
# 1. Python
# 2. R
# 3. Julia
# 4. SQL
# 5. Scala

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# 4. ggplot2
# 5. dplyr
# 6. tidyverse

# %% [markdown]
# | Data Science Tools|
# |---------------|
# | NLTK        |
# | Tensorflow  |
# | ggplot2     |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
#
# | Operation      | Example            |
# |---------------|------------------|
# | Multiplication| 2 * 3 = 6|
# | Division      | 6 / 3 = 2|
# | Addition      | 3 + 3 = 6|
# | Subtraction   | 3 - 2 = 1|

# %%
#Exercise 8 - Create a code cell to multiply and add numbers

(2+3)*6
# Out:
# 30

# %%
#Exercise 9 - Create a code cell to convert minutes to hours

time_in_minutes = int(input("What is the time in minutes?\n"))
time_in_hours = time_in_minutes / 60

print(f"The time in hours is {time_in_hours} hours")
# Out:
# The time in hours is 3.3333333333333335 hours

# %% [markdown]
# ## Author
# Olalekan Adekunle
